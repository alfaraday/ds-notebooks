# %% [markdown]
# IMPORTS
# ====

# %%
import quandl

# %%
quandl.ApiConfig.api_key = "F2kapHrJpa8wzY-MtpTg"

# %%
data = quandl.get("EIA/PET_RWTC_D")

# %%
data.shape
# Out:
# (8044, 1)

# %%
data.head()
# Out:
#             Value
# Date
# 1986-01-02  25.56
# 1986-01-03  26.00
# 1986-01-06  26.53
# 1986-01-07  25.85
# 1986-01-08  25.87

# %%
data.tail()
# Out:
#             Value
# Date
# 2017-10-31  54.36
# 2017-11-01  54.32
# 2017-11-02  54.55
# 2017-11-03  55.63
# 2017-11-06  57.34

# %%
data2 = quandl.get_table('MER/F1', compnumber=["39102", "2438"], paginate=True)

# %%
data2.shape
# Out:
# (2088, 32)

# %%
data2.head().transpose()
# Out:
# None                                  0                      1  \
# compnumber                         2438                   2438
# reportid                     1851368960             1851368960
# mapcode                           -3851                  -4340
# amount                             3.07              9.092e+09
# reportdate          2010-12-31 00:00:00    2010-12-31 00:00:00
# reporttype                            A                      A
# auditorstatus                         N                      N
# currency                            EUR                    EUR
# consolidated                       True                   True
# longname               Deutsche Bank AG       Deutsche Bank AG
# shortname              Deutsche Bank AG       Deutsche Bank AG
# status                           Active                 Active
# countrycode                         DEU                    DEU
# region                           Europe                 Europe
# ...

# %%
data2.columns
# Out:
# Index(['compnumber', 'reportid', 'mapcode', 'amount', 'reportdate',
#        'reporttype', 'auditorstatus', 'currency', 'consolidated', 'longname',
#        'shortname', 'status', 'countrycode', 'region', 'cik', 'mic', 'ticker',
#        'exchange', 'address1', 'address2', 'address3', 'address4', 'city',
#        'statecode', 'country', 'zipcode', 'phonenumber', 'faxnumber',
#        'website', 'fye', 'indicator', 'statement'],
#       dtype='object')

# %%
data3 = quandl.get_table('WIKI/PRICES', qopts = { 'columns': ['ticker', 'date', 'close'] }, ticker = ['AAPL', 'MSFT'], date = { 'gte': '2016-01-01', 'lte': '2016-12-31' })

# %%
data3.shape
# Out:
# (504, 3)

# %%
data3.head().transpose()
# Out:
# None                      0                    1                    2  \
# ticker                 AAPL                 AAPL                 AAPL
# date    2016-01-04 00:00:00  2016-01-05 00:00:00  2016-01-06 00:00:00
# close                105.35               102.71                100.7
#
# None                      3                    4
# ticker                 AAPL                 AAPL
# date    2016-01-07 00:00:00  2016-01-08 00:00:00
# close                 96.45                96.96

# %%
data3.tail().transpose()
# Out:
# None                    499                  500                  501  \
# ticker                 MSFT                 MSFT                 MSFT
# date    2016-12-23 00:00:00  2016-12-27 00:00:00  2016-12-28 00:00:00
# close                 63.24                63.28                62.99
#
# None                    502                  503
# ticker                 MSFT                 MSFT
# date    2016-12-29 00:00:00  2016-12-30 00:00:00
# close                  62.9                62.14

# %%
MER_F1 = quandl.get_table('MER/F1', paginate=True)
WIKI_PRICES = quandl.get_table('WIKI/PRICES', paginate=True)
# Out:
# ---------------------------------------------------------------------------
# LimitExceededError                        Traceback (most recent call last)
# <ipython-input-18-bb6b0e87f145> in <module>()
#       1 MER_F1 = quandl.get_table('MER/F1', paginate=True)
# ----> 2 WIKI_PRICES = quandl.get_table('WIKI/PRICES', paginate=True)
#
# /opt/ds/lib/python3.4/site-packages/quandl/get_table.py in get_table(datatable_code, **options)
#      27             raise LimitExceededError(
#      28                 Message.WARN_DATA_LIMIT_EXCEEDED % (datatable_code,
# ---> 29                                                     ApiConfig.api_key
#      30                                                     )
#      31             )
#
# ...
